# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
days= np.arange(0,7,1)

# %%
likes = [np.random.randint(100,400) for _ in range(len(days))]
# i did this

# %%
likes
# Out:
# [329, 118, 210, 359, 336, 387, 172]

# %%
plt.title("Social media Analysis")
plt.xlabel("Days")
plt.ylabel("Likes")
plt.plot(days,likes,color="red")
plt.grid()
